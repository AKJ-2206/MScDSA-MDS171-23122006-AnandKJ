# %%
class students:
    def __init__(self):
        self.details = {}

    def student_dtls (self,name, regno, batch, subject1 ,subject2 ,subject3 , total, percentage):
        total= subject1 + subject2 + subject3
        percentage = total*100/300
        self.dtls = {
            "name": name,
            "regno": regno,
            "batch": batch,
            "sub1": subject1,
            "sub2": subject2,
            "sub3" : subject3,
            "total": total,
            "percentage": percentage 
        }

        self.details[regno] = self.dtls
        print(self.dtls)
        #return reg_no
    def search(self,Reg):
        for key in self.dtls.keys():
            flag=True
            if Reg==key:
                print(self.dtls[key])
                exit()
            else:
                flag== "False"
        if flag=="False":
            print("Student not found")
obj=students()
